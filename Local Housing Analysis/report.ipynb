# %%
import numpy as np
from linear_regression import *
from qr_decomp import *
import matplotlib.pyplot as plt
import sklearn as sk

# %%
np.random.seed(42)

X = np.random.rand(50, 1) * 50  
coeff = np.array([[3.5]])
Y =  np.dot(X,coeff) + np.random.randn(50, 1) * 20
print(Y.shape)
# Out:
# (50, 1)

# %%
model = fit(X,Y,stepsize=0.00001, metric="mse")
print(f'Coefficients: {model[0]} \n Intercept: {model[1]} \n Error: {model[2]}')
# Out:
# Coefficients: [[3.41378033]]
#  Intercept: 1.8345837258528022
#  Error: 329.23132544935254

# %%
y_pred = predict(X,model[0],model[1])
plt.figure(figsize=(8,6)) 
plt.scatter(X, Y, color='blue', label='Data Points') 
plt.plot(X, y_pred.T, color='red', label='Custom Regression Line') 
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
model_sk = sk.linear_model.LinearRegression()
model_sk.fit(X,Y)
y_pred = model_sk.predict(X)
print(sk.metrics.mean_squared_error(Y, y_pred))
# Out:
# 329.2284574994752

# %%
Z = np.array([[12, -51, 4],
     [6, 167, -68],
     [-4, 24, -41]])
Q, R = householder(Z)
print(np.round(Q,3))
print(np.round(R,3))
# Out:
# [[ 0.857 -0.394  0.331]
#  [ 0.429  0.903 -0.034]
#  [-0.286  0.171  0.943]]
# [[ 14.  21. -14.]
#  [  0. 175. -70.]
#  [ -0.  -0. -35.]]

# %%
eq = np.hstack((np.ones((X.shape[0],1)),X))
beta = qr_solve(eq,Y)
print(beta)

y_pred = predict(X,beta[1],model[0])
plt.figure(figsize=(8,6)) 
plt.scatter(X, Y, color='blue', label='Data Points') 
plt.plot(X, y_pred.T, color='red', label='Custom Regression Line') 
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [-5.42114073  3.7405    ]
