# %%
import numpy as np

# %%
np.random.seed(42)

X = np.random.rand(3, 1) * 100  

Y = 3.5 * X + np.random.randn(3, 1) * 20

# %%
from linear_regression import *

model = fit(X,Y,stepsize=0.00001, metric="mse")
print(model)
# Out:
# (array([[0.52904314, 0.52904314, 0.52904314],
#        [1.64837031, 1.64837031, 1.64837031],
#        [1.27238562, 1.27238562, 1.27238562]]), array([[0.01412514],
#        [0.01733823],
#        [0.01738246]]), np.float64(4.0120413825000364e-26))
